# %%
import bp_module1

bp_module1.foo1()
# Out:
# Execute foo1

# %%
import bp_module1 as bpm

bpm.foo2()
# Out:
# 模块名： bp_module1
# Execute foo2

# %%
from bp_module1 import foo2, foo3

foo2()
foo3()
# Out:
# Execute foo2
# Execute foo3

# %%
from bp_module1 import foo1 as f1, foo2 as f2

f1()
f2()
# Out:
# Execute foo1
# Execute foo2

# %%
import bp_module1

print('模块名：', __name__)
# Out:
# 模块名： __main__
