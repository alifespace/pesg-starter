# %%
print("Hello Python!")
# Out:
# Hello Python!

# %%
import sqlite3
import os
import pandas as pd

# 数据库路径（与 notebook 同目录）
db_path = os.path.join(os.path.dirname("__file__"), "longlist0.db")

# 建立连接
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# 验证连接成功，并查看所有表
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
tables = cursor.fetchall()
print(f"✅ 已连接到 {db_path}")
print(f"📋 包含 {len(tables)} 张表：")
for t in tables:
    print(f"   - {t[0]}")
# Out:
# ✅ 已连接到 longlist0.db
# 📋 包含 3 张表：
#    - longlist
#    - sqlite_stat1
#    - sqlite_stat4

# %%
# 查询示例
df = pd.read_sql_query("SELECT * FROM longlist LIMIT 10", conn)
df
# Out:
#             isbn                                  title              author  \
# 0  9788439736967                                Boulder        Eva Baltasar
# 1  9781628971538                                  Whale   Cheon Myeong-Kwan
# 2  9781642861181  The Gospel According to the New World        Maryse Condé
# 3  9781529414431                         Standing Heavy                Gauz
# 4  9781474623025                           Time Shelter   Georgi Gospodinov
# 5  9781839764318                         Is Mother Dead       Vigdis Hjorth
# 6  9781529427820              Jimi Hendrix Live in Lviv       Andrey Kurkov
# 7  9781945492655                     The Birthday Party  Laurent Mauvignier
# 8  9781804270288                 While We Were Dreaming       Clemens Meyer
# 9  9781782278627                                   Pyre     Perumal Murugan
#
#                    translator     format  pages                publisher  \
# 0  Nicole d'Amonville Alegría  paperback    112  Literatura Random House
# 1               Jae Won Chung  paperback    368          Europa Editions
# 2             Richard Philcox  paperback    184           World Editions
# 3                 Frank Wynne  paperback    252          MacLehose Press
# 4                Angela Rodel  hardcover    304                      W&N
# 5          Charlotte Barslund  paperback    330            Verso Fiction
# 6              Reuben Woolley  hardcover    416          MacLehose Press
# 7         Daniel Levin Becker  paperback    454            Transit Books
# 8             Katy Derbyshire  paperback    528    Fitzcarraldo Editions
# 9        Aniruddhan Vasudevan  paperback    224            Pushkin Press
#
#     published  year  votes  rating
# 0  2022-08-02  2023   2779    3.77
# 1  2023-01-19  2023    175    3.97
# 2  2023-03-07  2023    114    3.05
# 3  2022-05-26  2023    322    3.57
# 4  2022-04-21  2023   3142    4.05
# 5  2022-09-27  2023   2455    3.76
# 6  2023-04-27  2023    167    3.64
# 7  2023-01-24  2023    529    3.83
# 8  2023-03-30  2023    705    4.00
# 9  2022-04-08  2023   1302    4.04

# %%
# 数据库适合存储大量结构化数据，尤其是关系型数据。它提供了高效的数据存储和查询能力，支持事务处理和数据完整性约束。
# 数据库优势包括：
# 1. 数据一致性：通过事务和约束，确保数据的完整性和一致性。
# 2. 高效查询：使用索引和优化的查询引擎，能够快速检索大量数据。
# 3. 并发访问：支持多用户同时访问和操作数据，适合团队协作。
# 4. 数据安全：提供权限管理和数据加密，保护敏感信息。
# 5. 可扩展性：适用于从小型应用到大型企业级系统的各种场景。
# CRUD 操作是数据库的基本操作，包括
# 创建（Create）、读取（Read）、更新（Update）和删除（Delete）数据。通过这些操作，用户可以对数据库中的数据进行管理和维护。

# SQL: Structured Query Language（结构化查询语言），是一种用于管理和操作关系型数据库的标准语言。
# SQL 提供了丰富的语法和功能，用于执行数据查询、插入、更新、删除以及数据库结构定义等操作。
# 通过 SQL，用户可以高效地与数据库进行交互，实现数据的存储、检索和分析。

# df = pd.read_sql_query("SELECT * FROM books LIMIT 10", conn)
# df

# SQL是一种声明式语言，用户只需描述想要的数据结果，而不需要指定具体的操作步骤。SQL的核心功能包括：
df = pd.read_sql_query('SELECT title FROM longlist LIMIT 10', conn)
df

df = pd.read_sql_query('SELECT title from longlist LIMIT 5', conn)
df
# Out:
#                                    title
# 0                                Boulder
# 1                                  Whale
# 2  The Gospel According to the New World
# 3                         Standing Heavy
# 4                           Time Shelter

# %%
df = pd.read_sql_query('SELECT title, author FROM longlist WHERE year = 2023', conn)
df
# Out:
#                                      title              author
# 0                                  Boulder        Eva Baltasar
# 1                                    Whale   Cheon Myeong-Kwan
# 2    The Gospel According to the New World        Maryse Condé
# 3                           Standing Heavy                Gauz
# 4                             Time Shelter   Georgi Gospodinov
# 5                           Is Mother Dead       Vigdis Hjorth
# 6                Jimi Hendrix Live in Lviv       Andrey Kurkov
# 7                       The Birthday Party  Laurent Mauvignier
# 8                   While We Were Dreaming       Clemens Meyer
# 9                                     Pyre     Perumal Murugan
# 10                              Still Born    Guadalupe Nettel
# 11  A System So Magnificent It Is Blinding     Amanda Svensson
# 12                          Ninth Building         Zou Jingzhi

# %%
# SQL中不等于有两种写法：<> 和 !=，它们的作用相同，都是用于表示不等于的条件。
# 不同数据库系统可能对这两种写法的支持有所不同，但在大多数情况下，它们是可以互换使用的。

df = pd.read_sql_query('SELECT title, format FROM longlist WHERE format != \'Hardcover\'', conn)
df
# Out:
#                                     title     format
# 0                                 Boulder  paperback
# 1                                   Whale  paperback
# 2   The Gospel According to the New World  paperback
# 3                          Standing Heavy  paperback
# 4                            Time Shelter  hardcover
# ..                                    ...        ...
# 73                         The White Book  paperback
# 74                      The World Goes On  paperback
# 75                       Vernon Subutex 1  paperback
# 76                           Die, My Love  paperback
# 77                                Flights  paperback
#
# [78 rows x 2 columns]

# %%
# NOT: 用于在 SQL 查询中表示逻辑非操作，通常用于条件表达式中，以排除满足特定条件的记录。

df = pd.read_sql_query('SELECT title, author FROM longlist WHERE NOT format = \'Hardcover\'', conn)
df
# Out:
#                                     title                author
# 0                                 Boulder          Eva Baltasar
# 1                                   Whale     Cheon Myeong-Kwan
# 2   The Gospel According to the New World          Maryse Condé
# 3                          Standing Heavy                  Gauz
# 4                            Time Shelter     Georgi Gospodinov
# ..                                    ...                   ...
# 73                         The White Book              Han Kang
# 74                      The World Goes On  László Krasznahorkai
# 75                       Vernon Subutex 1    Virginie Despentes
# 76                           Die, My Love        Ariana Harwicz
# 77                                Flights        Olga Tokarczuk
#
# [78 rows x 2 columns]

# %%
# 逻辑运算符 AND 和 OR 用于在 SQL 查询中组合多个条件，以实现更复杂的筛选逻辑。

df = pd.read_sql_query('SELECT title, author FROM longlist WHERE year = 2022 OR year = 2023', conn)
df
# Out:
#                                      title                   author
# 0                                  Boulder             Eva Baltasar
# 1                                    Whale        Cheon Myeong-Kwan
# 2    The Gospel According to the New World             Maryse Condé
# 3                           Standing Heavy                     Gauz
# 4                             Time Shelter        Georgi Gospodinov
# 5                           Is Mother Dead            Vigdis Hjorth
# 6                Jimi Hendrix Live in Lviv            Andrey Kurkov
# 7                       The Birthday Party       Laurent Mauvignier
# 8                   While We Were Dreaming            Clemens Meyer
# 9                                     Pyre          Perumal Murugan
# 10                              Still Born         Guadalupe Nettel
# 11  A System So Magnificent It Is Blinding          Amanda Svensson
# 12                          Ninth Building              Zou Jingzhi
# 13                                Paradais         Fernanda Melchor
# 14                                  Heaven           Mieko Kawakami
# 15                    Love in the Big City          Sang Young Park
# 16                   Happy Stories, Mostly  Norman Erikson Pasaribu
# 17                             Elena Knows          Claudia Piñeiro
# 18                      The Book of Mother         Violaine Huisman
# 19                More Than I Love My Life           David Grossman
# 20                              Phenotypes              Paulo Scott
# 21            A New Name: Septology VI-VII                Jon Fosse
# 22                           After the Sun               Jonas Eika
# 23                            Tomb of Sand        Geentanjali Shree
# 24                      The Books of Jacob           Olga Tokarczuk
# 25                            Cursed Bunny               Bora Chung

# %%
df = pd.read_sql_query('SELECT title, author, format FROM longlist WHERE year = 2022 OR year = 2023 AND format = \'Paperback\'', conn)
df
# Out:
#                            title                   author     format
# 0                       Paradais         Fernanda Melchor  paperback
# 1                         Heaven           Mieko Kawakami  paperback
# 2           Love in the Big City          Sang Young Park  paperback
# 3          Happy Stories, Mostly  Norman Erikson Pasaribu  paperback
# 4                    Elena Knows          Claudia Piñeiro  paperback
# 5             The Book of Mother         Violaine Huisman  paperback
# 6       More Than I Love My Life           David Grossman  paperback
# 7                     Phenotypes              Paulo Scott  paperback
# 8   A New Name: Septology VI-VII                Jon Fosse  paperback
# 9                  After the Sun               Jonas Eika  paperback
# 10                  Tomb of Sand        Geentanjali Shree  paperback
# 11            The Books of Jacob           Olga Tokarczuk  paperback
# 12                  Cursed Bunny               Bora Chung  paperback

# %%
# NULL: 用于表示缺失或未知的值。在 SQL 查询中，可以使用 IS NULL 或 IS NOT NULL 来筛选包含或不包含 NULL 值的记录。
df = pd.read_sql_query('SELECT title, author, translator FROM longlist WHERE translator IS NULL', conn)
df
# Out:
#                                      title             author translator
# 0                         The Perfect Nine  Ngũgĩ wa Thiong'o       None
# 1  The Enlightenment of The Greengage Tree     Shokoofeh Azar       None

# %%
df = pd.read_sql_query('SELECT title, author, translator FROM longlist WHERE translator IS NOT NULL', conn)
df
# Out:
#                                     title                author  \
# 0                                 Boulder          Eva Baltasar
# 1                                   Whale     Cheon Myeong-Kwan
# 2   The Gospel According to the New World          Maryse Condé
# 3                          Standing Heavy                  Gauz
# 4                            Time Shelter     Georgi Gospodinov
# ..                                    ...                   ...
# 71                         The White Book              Han Kang
# 72                      The World Goes On  László Krasznahorkai
# 73                       Vernon Subutex 1    Virginie Despentes
# 74                           Die, My Love        Ariana Harwicz
# 75                                Flights        Olga Tokarczuk
#
#                                         translator
# 0                       Nicole d'Amonville Alegría
# 1                                    Jae Won Chung
# 2                                  Richard Philcox
# 3                                      Frank Wynne
# 4                                     Angela Rodel
# ..                                             ...
# 71                                   Deborah Smith
# 72  Ottilie Mulzet, George Szirtes, and John Batki
# 73                                     Frank Wynne
# 74                 Sarah Moses and Carolina Orloff
# 75                                  Jennifer Croft
#
# [76 rows x 3 columns]

# %%
#LIKE: 用于在 SQL 查询中进行模糊匹配，通常与通配符（如 % 和 _）结合使用，以查找符合特定模式的记录。
# %: 表示任意数量的字符（包括零个字符）。
# _: 表示单个字符。
df = pd.read_sql_query('SELECT title FROM longlist WHERE title LIKE \'%love%\'', conn)
df
# Out:
#                         title
# 0        Love in the Big City
# 1    More Than I Love My Life
# 2  Love in the New Millennium
# 3                Die, My Love

# %%
df = pd.read_sql_query('SELECT title, author FROM longlist WHERE title LIKE \'the %\'', conn)
df
# Out:
#                                       title                   author
# 0     The Gospel According to the New World             Maryse Condé
# 1                        The Birthday Party       Laurent Mauvignier
# 2                        The Book of Mother         Violaine Huisman
# 3                        The Books of Jacob           Olga Tokarczuk
# 4                       The War of the Poor            Éric Vuillard
# 5             The Dangers of Smoking in Bed         Mariana Enríquez
# 6                             The Employees                Olga Ravn
# 7                            The Pear Field       Nana Ekvtimishvili
# 8                          The Perfect Nine        Ngũgĩ wa Thiong'o
# 9              The Adventures of China Iron  Gabriela Cabezón Cámara
# 10                The Discomfort of Evening  Marieke Lucas Rijneveld
# 11                          The Eighth Life       Nino Haratischvili
# 12  The Enlightenment of The Greengage Tree           Shokoofeh Azar
# 13                        The Memory Police               Yōko Ogawa
# 14           The Other Name: Septology I-II                Jon Fosse
# 15               The Death of Murat Idrissi           Tommy Wieringa
# 16                    The Faculty of Dreams          Sara Stridsberg
# 17                         The Pine Islands         Marion Poschmann
# 18                            The Remainder      Alia Trabucco Zerán
# 19                   The Shape of the Ruins     Juan Gabriel Vásquez
# 20                                The Years             Annie Ernaux
# 21             The 7th Function of Language            Laurent Binet
# 22                         The Dinner Guest          Gabriela Ybarra
# 23                      The Flying Mountain       Christoph Ransmayr
# 24                             The Impostor            Javier Cercas
# 25                       The Stolen Bicycle               Wu Ming-Yi
# 26                           The White Book                 Han Kang
# 27                        The World Goes On     László Krasznahorkai
