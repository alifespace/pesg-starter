# %%
import sys

def xxx():
  sex = input('请输入性别')
  if sex == 'boy':
    print('男孩')
  elif sex == 'girl':
    print('女孩')
  else:
    raise Exception('Invalid')

try:
  xxx()
except Exception as e:
  print('发生错误：', e)
  # raise   # raise执行了之后，后面的代码就不会执行了
  # sys.exit()

# sys.exit()
print('执行完毕')
# Out:
# 发生错误： Invalid
# 执行完毕

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# c:\Prjcenter\pesg-starter\.venv\Lib\site-packages\IPython\core\interactiveshell.py:3755: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
