# %%
num1 = 60   # 全局变量

def func1():
  print(num1)

print(num1)
func1()
# Out:
# 60
# 60

# %%
num1 = 60

def func1():
  global num1
  num1 += 1

func1()
print(num1)
# Out:
# 61

# %%
import os

if 'COLAB_TPU_ADDR' in os.environ:
    print(f"✅ 成功连接到 TPU！")
    print(f"TPU 地址: {os.environ['COLAB_TPU_ADDR']}")
else:
    print("❌ 当前未连接 TPU 或未识别到 TPU 环境。")
# Out:
# ❌ 当前未连接 TPU 或未识别到 TPU 环境。
